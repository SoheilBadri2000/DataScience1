# %% [markdown]
# <a href="https://colab.research.google.com/github/SoheilBadri2000/DataScience1/blob/main/3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 import numpy as np
 import matplotlib.pyplot as plt

# %%
from matplotlib.figure import projections
fig = plt.figure(dpi=100)
plt.rcParams["figure.figsize"] = (5,5)
ax = fig.add_subplot(111, projection="3d")

xx = np.arange(-20, 20, 0.1)
yy = np.arange(-20, 20, 0.1)
X, Y, = np.meshgrid(xx, yy)
Z = X**2 + Y**2

ax.plot_surface(X, Y, Z, cmap="viridis", lw=0.5, rstride=1,  cstride=1)
ax.contour(X, Y, Z, 10, lw=2, cmap="viridis", linestyles="solid", offset=-1)
ax.contour(X, Y, Z, 10, lw=2, colors="k", linestyles="solid")
plt.show()
# Out:
# <ipython-input-8-55656b11ee12>:12: UserWarning: The following kwargs were not used by contour: 'lw'
#   ax.contour(X, Y, Z, 10, lw=2, cmap="viridis", linestyles="solid", offset=-1)
# <ipython-input-8-55656b11ee12>:13: UserWarning: The following kwargs were not used by contour: 'lw'
#   ax.contour(X, Y, Z, 10, lw=2, colors="k", linestyles="solid")
